# %%
# 1. Write a code to create a string with your name and print it. 
name = "Subham Prakash Swain"
print(name)
# Out:
# Subham Prakash Swain

# %%
# 2. Write a code to findthe length of the string "Hello World". 
print(len("Hello World"))
# Out:
# 11

# %%
# 3. write a code to slice the first 3 characters from the string "Python Programing".
string = "Python Programing"
sliced_string = string[:3]
print(sliced_string)
# Out:
# Pyt

# %%
# 4. write the code to convert the string "hello" to uppercase.
string = "hello"
uppercase_string = string.upper()
print(uppercase_string)
# Out:
# HELLO

# %%
# 5. write a code to replace the word "apple" with "orange" in the string "I like apple".
string = "I like apple"
new_string = string.replace("apple", "orange")
print(new_string)
# Out:
# I like orange

# %%
# 6. write a code to creat list with numbers from 1 to 5 and print it.
numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7. write a code append the number 10 to the list [1,2,3,4].
numbers = [1, 2, 3, 4]
numbers.append(10)
print(numbers)
# Out:
# [1, 2, 3, 4, 10]

# %%
# 8. write a code to remove the number 3 from the list [1,2,3,4,5].
numbers = [1, 2, 3, 4, 5]
numbers.remove(3)
print(numbers)
# Out:
# [1, 2, 4, 5]

# %%
# 9. write a code to access the second element from the list ['a','b','c','d'].
letters = ['a', 'b', 'c', 'd']
print(letters[1])
# Out:
# b

# %%
# 10. write a code to reverse the list [10,20,30,40,50].
numbers = [10, 20, 30, 40, 50]
numbers.reverse()
print(numbers)
# Out:
# [50, 40, 30, 20, 10]

# %%
# 11. write a code to create a touple with the elements 100, 200, 300 and print it.
my_tuple = (100, 200, 300)
print(my_tuple)
# Out:
# (100, 200, 300)

# %%
# 12. write a code to access the second to last elementof the touple ('red', 'green', 'blue', 'yellow').
colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])
# Out:
# blue

# %%
# 13. write a code to find the minimum number in the touple (10, 20, 5, 15).
numbers = (10, 20, 5, 15)
print(min(numbers))
# Out:
# 5

# %%
# 14. write the code to find the index of the element "cat" in touple ('dog', 'cat', 'mouse').
animals = ('dog', 'cat', 'mouse')
print(animals.index('cat'))
# Out:
# 1

# %%
#15. write a code to creat a touple containing three different fruits and cheak if "kiwi" is in it.
fruits = ('jack fruit', 'tomato', 'kiwi')
print("kiwi" in fruits)
# Out:
# True

# %%
# 16. write a code to creat a set with the elements 'a', 'b', 'c' and print it.
my_set = {'a', 'b', 'c'}
print(my_set)
# Out:
# {'b', 'a', 'c'}

# %%
# 17. write a cod to clear all elements from the set {1,2,3,4}.
my_set = {1, 2, 3, 4}
my_set.clear()
print(my_set)
# Out:
# set()

# %%
# 18. write a code to remove the element4 from the set {1,2,3,4}.
my_set = {1, 2, 3, 4}
my_set.remove(4)
print(my_set)
# Out:
# {1, 2, 3}

# %%
# 19. write a code to find the union of two sets{1,2,3} and {3,4,5}.
set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1.union(set2)
print(union_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
# 20. write a code to find the intersection of two sets {1,2,3} and {2,3,4}.
set1 = {1, 2, 3}
set2 = {2, 3, 4}
intersection_set = set1.intersection(set2)
print(intersection_set)
# Out:
# {2, 3}

# %%
# 21. write a code to creat a dictionary with the keys "name", "age", and "city" , and print it. 
my_dict = {"name": "Alice", "age": 30, "city": "New York"}
print(my_dict)
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
# 22. write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'jhon', 'age': 25}.
my_dict = {'name': 'jhon', 'age': 25}
my_dict['country'] = 'USA'
print(my_dict)
# Out:
# {'name': 'jhon', 'age': 25, 'country': 'USA'}

# %%
# 23. write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
my_dict = {'name': 'Alice', 'age': 30}
print(my_dict['name'])
# Out:
# Alice

# %%
# 24. write a code to remove the key "age" from the dictionary {'name':'Bob', 'age': 22, 'city': 'chikago}.
my_dict = {'name':'Bob', 'age': 22, 'city': 'chikago'}
del my_dict['age']
print(my_dict)
# Out:
# {'name': 'Bob', 'city': 'chikago'}

# %%
# 25. write a code to check if the key "city" exists in the dictionary{'name' : 'Alice', 'city': 'New York}. 
my_dict = {'name' : 'Alice', 'city': 'New York'}
if 'city' in my_dict:
    print("Key 'city' exists in the dictionary.")
else:
    print("Key 'city' does not exist in the dictionary.")
# Out:
# Key 'city' exists in the dictionary.

# %%
# 26. write a code to creat a list , a touple , a set and a dictionary and print them all.
my_list = [1, 2, 3]
my_tuple = (1, 2, 3)
my_set = {1, 2, 3}
my_dict = {"name": "Alice", "age": 30, "city": "New York"}
print("List:", my_list)
print("Tuple:", my_tuple)
print("Set:", my_set)
print("Dictionary:", my_dict)
# Out:
# List: [1, 2, 3]
# Tuple: (1, 2, 3)
# Set: {1, 2, 3}
# Dictionary: {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.
import random
random_numbers = [random.randint(1, 100) for _ in range(5)]
random_numbers.sort()
print(random_numbers)
# Out:
# [23, 51, 55, 75, 84]

# %%
# 28.  Write a code to create a list with strings and print the element at the third index.
string_list = ["apple", "banana", "cherry", "date", "elderberry"]
print(string_list[3])
# Out:
# date

# %%
# 29. Write a code to combine two dictionaries into one and print the result.
dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}
combined_dict = {**dict1, **dict2}
print(combined_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# 30. Write a code to convert a list of strings into a set.
string_list = ["apple", "banana", "cherry", "date", "elderberry"]
string_set = set(string_list)
print(string_set)
# Out:
# {'apple', 'elderberry', 'banana', 'date', 'cherry'}
