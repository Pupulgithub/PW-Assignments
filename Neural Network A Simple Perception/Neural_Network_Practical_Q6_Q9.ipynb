# %% [markdown]
# # Neural Network - A Simple Perceptron (Practical Questions Q6-Q9)

# %% [markdown]
# ## Question 6

# %%
# Python solution for Question 6
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 7

# %%
# Python solution for Question 7
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 8

# %%
# Python solution for Question 8
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 9

# %%
# Python solution for Question 9
# Run this code in Jupyter Notebook
