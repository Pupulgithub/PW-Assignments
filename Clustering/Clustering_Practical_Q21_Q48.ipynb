# %% [markdown]
# # Clustering Practical Questions (Q21-Q48)

# %% [markdown]
# ## Question 21

# %%
# Python solution for Question 21
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 22

# %%
# Python solution for Question 22
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 23

# %%
# Python solution for Question 23
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 24

# %%
# Python solution for Question 24
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 25

# %%
# Python solution for Question 25
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 26

# %%
# Python solution for Question 26
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 27

# %%
# Python solution for Question 27
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 28

# %%
# Python solution for Question 28
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 29

# %%
# Python solution for Question 29
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 30

# %%
# Python solution for Question 30
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 31

# %%
# Python solution for Question 31
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 32

# %%
# Python solution for Question 32
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 33

# %%
# Python solution for Question 33
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 34

# %%
# Python solution for Question 34
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 35

# %%
# Python solution for Question 35
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 36

# %%
# Python solution for Question 36
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 37

# %%
# Python solution for Question 37
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 38

# %%
# Python solution for Question 38
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 39

# %%
# Python solution for Question 39
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 40

# %%
# Python solution for Question 40
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 41

# %%
# Python solution for Question 41
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 42

# %%
# Python solution for Question 42
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 43

# %%
# Python solution for Question 43
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 44

# %%
# Python solution for Question 44
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 45

# %%
# Python solution for Question 45
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 46

# %%
# Python solution for Question 46
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 47

# %%
# Python solution for Question 47
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 48

# %%
# Python solution for Question 48
# Run this code in Jupyter Notebook
