# %% [markdown]
# # Ensemble Learning Practical Answers (Q6-Q9)

# %% [markdown]
# ## Question 6

# %%
# Answer for Question 6
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 7

# %%
# Answer for Question 7
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 8

# %%
# Answer for Question 8
# Run this code in Jupyter Notebook

# %% [markdown]
# ## Question 9

# %%
# Answer for Question 9
# Run this code in Jupyter Notebook
