# %% [markdown]
# 1. What is NumPy, and why is it widely used in Python?
#
# NumPy is a core Python library for numerical computing. It provides fast, memory-efficient multidimensional arrays and mathematical functions optimized in C.
#
# Why widely used:
#
# High performance for numerical operations
#
# Vectorized computations
#
# Foundation for Pandas, SciPy, and ML libraries

# %% [markdown]
# 2. How does broadcasting work in NumPy?
#
# Broadcasting allows NumPy to perform arithmetic operations on arrays of different shapes by automatically expanding smaller arrays without copying data.

# %%
import numpy as np
a = np.array([1, 2, 3])
b = 10
print(a + b)
# Out:
# [11 12 13]

# %% [markdown]
# 3. What is a Pandas DataFrame?
#
# A DataFrame is a 2-dimensional labeled data structure with rows and columns, similar to a table in SQL or Excel.

# %% [markdown]
# 4. Explain the use of groupby() in Pandas
#
# groupby() is used to split data into groups and apply aggregation functions.

# %%
df.groupby("Department")["Salary"].mean()

# %% [markdown]
# 5. Why is Seaborn preferred for statistical visualizations?
#
# Seaborn provides high-level statistical plots with better default aesthetics and built-in dataset handling.

# %% [markdown]
# 6. Differences between NumPy arrays and Python lists
# | Feature       | NumPy Array | Python List   |
# | ------------- | ----------- | ------------- |
# | Speed         | Faster      | Slower        |
# | Data Type     | Homogeneous | Heterogeneous |
# | Vectorization | Supported   | Not supported |

# %% [markdown]
# 7. What is a heatmap and when should it be used?
#
# A heatmap visualizes values using colors. It is best for correlation matrices and pattern detection.

# %% [markdown]
# 8. What does “vectorized operation” mean in NumPy?
#
# Operations applied to entire arrays without explicit loops, improving speed and readability.

# %% [markdown]
# 9. How does Matplotlib differ from Plotly?
#
# Matplotlib: Static, publication-ready plots
#
# Plotly: Interactive, web-based visualizations

# %% [markdown]
# 10. Significance of hierarchical indexing in Pandas
#
# Allows multi-level indexing for complex data structures, useful in time series and grouped datasets.

# %% [markdown]
# 11. Role of Seaborn’s pairplot()
#
# Displays pairwise relationships between numerical features for exploratory data analysis.

# %% [markdown]
# 12. Purpose of describe() in Pandas
#
# Provides summary statistics such as mean, std, min, max, and quartiles.

# %% [markdown]
# 13. Why is handling missing data important in Pandas?
#
# Missing values can distort analysis and ML models if not handled properly.

# %% [markdown]
# 14. Benefits of Plotly
#
# Interactive zoom and hover
#
# Web-friendly
#
# Supports 3D visualizations

# %% [markdown]
# 15. How does NumPy handle multidimensional arrays?
#
# Using ndarray with shape, ndim, and axis-based operations.

# %% [markdown]
# 16. Role of Bokeh
#
# Bokeh is used for interactive, browser-based visualizations and dashboards.

# %% [markdown]
# 17. Difference between apply() and map()
#
# map() → Series only
#
# apply() → DataFrame or Series

# %% [markdown]
# 18. Advanced features of NumPy
#
# Broadcasting
#
# Memory views
#
# Linear algebra module
#
# Random sampling

# %% [markdown]
# 19. How does Pandas simplify time series analysis?
#
# Built-in datetime indexing, resampling, rolling windows, and frequency handling.

# %% [markdown]
# 20. Role of pivot tables in Pandas
#
# Summarizes data using aggregation functions.

# %%
pd.pivot_table(df, values="Sales", index="Region", aggfunc="sum")

# %% [markdown]
# 21. Why is NumPy slicing faster than Python lists?
#
# NumPy uses views instead of copying data, reducing memory overhead.

# %% [markdown]
# 22. Common use cases for Seaborn
#
# Distribution analysis
#
# Correlation analysis
#
# Regression plots
